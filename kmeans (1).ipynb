# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as pimg
import matplotlib.colors
from mpl_toolkits.mplot3d import Axes3D
import random
import os

from IPython.display import display, Math, Latex, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
class KMeans():
        def __init__(self,k):
            self.k = k
            self.DMeasure = []
            
        def InitiliseCentroids(self,X):
            # Assigning Random k-points as Clusters"
            N = X.shape[1]
            Ind = np.random.randint(N,size=(self.k,))
            G = []
            for i in Ind:
                G.append(X[:,i])
                
            return np.transpose(G)
        
        def DistortionMeasure(self,r,X,Centroids):
            # Calculating Distortion Measure
            
            #Distances: Distance of Each Data Point from each Centriod. Shape:(n,k)
            
            Distances = np.linalg.norm((np.repeat(np.expand_dims(X,axis=1),self.k,axis=1)- np.expand_dims(Centroids,axis=-1)), axis=0)
            J = np.sum(np.multiply(Distances,r))
            
            return J
        
        def ClusterData(self,X,Centroids):
            # Assigning Cluster to Each Point in X
            N = X.shape[1]
            r = np.zeros((self.k,N))
            
            Distances = np.linalg.norm((np.repeat(np.expand_dims(X,axis=1),self.k,axis=1)- np.expand_dims(Centroids,axis=-1)), axis=0)
            Clusters = np.argmin(Distances,axis=0)
            
            # Representing Clusters as 1-of-K Representation\n",
            r = np.transpose(np.eye(self.k)[Clusters])
                
            return r
        
        def CalculateCentroids(self,X,r):
            # Calculating Centroids
            d = X.shape[0]
            Centroids = np.zeros((d,self.k))
            
            Num = np.matmul(X,np.transpose(r))
            Den = np.sum(r,axis=1)
            Centroids = np.divide(Num,np.repeat(np.expand_dims(Den,axis=0),d,axis=0))
            return Centroids
            
            
        def fit(self,X,Epsilon):
            # Iterating over all Data Points
            Centroids = self.InitiliseCentroids(X)
            Loss = []
            e = 0
            
            while 1:
                r = self.ClusterData(X,Centroids)
                J = self.DistortionMeasure(r,X,Centroids)
                NCentroids = self.CalculateCentroids(X,r)
                Diff = np.sum(np.linalg.norm(np.abs(NCentroids-Centroids),axis=1))
                print ("Epoch/Iteration: %-*s  Error in Centroids: %-*s  Distortion Measure: %s" % (6,e,24,Diff,J))
                Loss.append(Diff)
                e += 1
                if Diff < Epsilon:
                    break
                    
                Centroids = NCentroids
    
            return Loss,np.argmax(r,axis=0),Centroids
                    
        def LossPlot(self,Loss):
            # Plotting Loss\n",
            
            #Loss: Loss Data/ Distortion Measures before Each Iteration
            
            Loss = np.array(Loss)
            
            plt.figure(figsize=(8,6))
            plt.plot(np.arange(Loss.shape[0]),Loss)
            plt.grid()
            plt.title("Loss")
            plt.xlabel('Epochs/Iterations')
            plt.ylabel('Error in Centroids')
            plt.show()
            
        def PlotClusters(self,X,y):
            # Plotting Clusters\n",
            
            #y: Labels of Data Points
            
            fig = plt.figure(figsize=(8,8))
            ax = fig.add_subplot(111, projection='3d')
            plt.title("Clustering Data")
            ax.scatter(X[0],X[1],X[2],c=y,cmap='jet')
            ax.set_xlabel("R")
            ax.set_ylabel("G")
            ax.set_zlabel("B")
            plt.ioff()
            plt.show()
            
        def ClusteredOutput(self,X,Labels,Centroids):
            # Returning Data after assigning to Clusters\n",
            
            #Labels: Labels of Data Points
            
            Y = np.zeros(X.shape)
    
            for i in range(X.shape[1]):
                Y[:,i] = Centroids[:,Labels[i]]
    
            return Y

# %%
I = pimg.imread('4.2.07.tiff')
plt.figure(figsize=(6,6))
plt.imshow(I)
plt.show()

# %%
X = np.transpose(I.reshape(-1,3))

NClusters = 7
Epsilon = 0.0005

Algorithm = KMeans(NClusters)
Loss,Labels,Centroids = Algorithm.fit(X,Epsilon)
print("---------------------------------------")
print ("Centroids at Convergence:\n", Centroids)
# Out:
# Epoch/Iteration: 0       Error in Centroids: 247.98520562351808        Distortion Measure: 28367453.07442395
# Epoch/Iteration: 1       Error in Centroids: 155.6435418852647         Distortion Measure: 12962435.10795121
# Epoch/Iteration: 2       Error in Centroids: 104.36444088457476        Distortion Measure: 10498777.12725807
# Epoch/Iteration: 3       Error in Centroids: 43.33679755937426         Distortion Measure: 8670175.870284075
# Epoch/Iteration: 4       Error in Centroids: 34.27460603175576         Distortion Measure: 7960201.584627988
# Epoch/Iteration: 5       Error in Centroids: 22.980710918877303        Distortion Measure: 7578232.276164327
# Epoch/Iteration: 6       Error in Centroids: 16.319578212179298        Distortion Measure: 7453149.882656166
# Epoch/Iteration: 7       Error in Centroids: 12.53995880678357         Distortion Measure: 7408419.536927417
# Epoch/Iteration: 8       Error in Centroids: 12.176144206165379        Distortion Measure: 7393983.521532904
# Epoch/Iteration: 9       Error in Centroids: 8.834338026018218         Distortion Measure: 7388995.890028767
# Epoch/Iteration: 10      Error in Centroids: 8.966364925838928         Distortion Measure: 7383075.416935465
# Epoch/Iteration: 11      Error in Centroids: 11.42870583210408         Distortion Measure: 7369383.105557963
# Epoch/Iteration: 12      Error in Centroids: 14.730140276579226        Distortion Measure: 7335055.903234271
# Epoch/Iteration: 13      Error in Centroids: 15.570953539501103        Distortion Measure: 7273050.324565246
# Epoch/Iteration: 14      Error in Centroids: 12.623873957766273        Distortion Measure: 7207716.274103163
# Epoch/Iteration: 15      Error in Centroids: 9.380666369797812         Distortion Measure: 7162280.047580803
# Epoch/Iteration: 16      Error in Centroids: 7.285878838206123         Distortion Measure: 7131766.940767777
# Epoch/Iteration: 17      Error in Centroids: 5.993853512058217         Distortion Measure: 7108647.965488711
# Epoch/Iteration: 18      Error in Centroids: 5.016917720197776         Distortion Measure: 7090964.331339184
# Epoch/Iteration: 19      Error in Centroids: 4.282296378312768         Distortion Measure: 7077138.913451685
# Epoch/Iteration: 20      Error in Centroids: 3.5906074914326247        Distortion Measure: 7066306.379825529
# Epoch/Iteration: 21      Error in Centroids: 2.8138658097673477        Distortion Measure: 7058194.611425171
# Epoch/Iteration: 22      Error in Centroids: 2.2255099901874           Distortion Measure: 7052566.33247111
# Epoch/Iteration: 23      Error in Centroids: 1.7987389447493494        Distortion Measure: 7048692.895196913
# Epoch/Iteration: 24      Error in Centroids: 1.5114671520034837        Distortion Measure: 7045779.453538783
# Epoch/Iteration: 25      Error in Centroids: 1.3059064217671903        Distortion Measure: 7043463.472167571
# Epoch/Iteration: 26      Error in Centroids: 1.0035636562972161        Distortion Measure: 7041712.198957199
# Epoch/Iteration: 27      Error in Centroids: 0.7979810112027728        Distortion Measure: 7040428.144863309
# Epoch/Iteration: 28      Error in Centroids: 0.6034056762592162        Distortion Measure: 7039378.075437457
# Epoch/Iteration: 29      Error in Centroids: 0.4835191278343215        Distortion Measure: 7038545.663383026
# Epoch/Iteration: 30      Error in Centroids: 0.3984499993283188        Distortion Measure: 7037914.280362032
# Epoch/Iteration: 31      Error in Centroids: 0.3295811357440133        Distortion Measure: 7037316.822812822
# Epoch/Iteration: 32      Error in Centroids: 0.24029191148425266       Distortion Measure: 7036941.769760307
# Epoch/Iteration: 33      Error in Centroids: 0.18186307053395928       Distortion Measure: 7036636.565028189
# Epoch/Iteration: 34      Error in Centroids: 0.10534716314712163       Distortion Measure: 7036422.427453427
# Epoch/Iteration: 35      Error in Centroids: 0.09813063326118107       Distortion Measure: 7036290.793376415
# Epoch/Iteration: 36      Error in Centroids: 0.08423300943343756       Distortion Measure: 7036201.503362741
# Epoch/Iteration: 37      Error in Centroids: 0.06603836702368994       Distortion Measure: 7036096.47834824
# Epoch/Iteration: 38      Error in Centroids: 0.04169825900782709       Distortion Measure: 7036035.082222747
# Epoch/Iteration: 39      Error in Centroids: 0.02470580872493943       Distortion Measure: 7036000.446725368
# Epoch/Iteration: 40      Error in Centroids: 0.018671724945413155      Distortion Measure: 7035977.161699703
# Epoch/Iteration: 41      Error in Centroids: 0.008872385396519075      Distortion Measure: 7035969.918279314
# Epoch/Iteration: 42      Error in Centroids: 0.00871224647617905       Distortion Measure: 7035952.872331095
# Epoch/Iteration: 43      Error in Centroids: 0.004013344456855598      Distortion Measure: 7035957.299178169
# Epoch/Iteration: 44      Error in Centroids: 0.0                       Distortion Measure: 7035946.0217930265
# ---------------------------------------
# Centroids at Convergence:
#  [[118.73620796 167.81801451 187.86196304 195.72914865 194.4981185
#   128.72539269  61.39016135]
#  [150.78306841 193.84217201 212.21841164 107.59730631  47.78290784
#    41.73406513   4.94022039]
#  [ 71.67281988  92.19210009 174.38273657  67.11380205  41.46463883
#    31.20777488   4.59350649]]

# %%
Algorithm.PlotClusters(X,Labels)

# %%
Algorithm.LossPlot(Loss)

# %%
Y = np.transpose(Algorithm.ClusteredOutput(X,Labels,Centroids))
J = np.round(np.reshape(Y,I.shape)).astype(int)

plt.figure(figsize=(12,24))

plt.subplot(1,2,1)
plt.imshow(I)
plt.title('Original Image')

plt.subplot(1,2,2)
plt.imshow(J)
plt.title('Image after Clustering using K-Means')

plt.show()
